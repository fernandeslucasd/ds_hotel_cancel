# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  cancellation_prediction.csv
# 'Desafio Cientista de Dados - Booking cancellation_novo.pdf'
#  initial_analysis.ipynb
#  initial_model.ipynb

# %%
df = pd.read_csv('cancellation_prediction.csv')
df.head(10)
# Out:
#           type  cancellation  days_between_booking_arrival  year_arrival_date  \
# 0  Fancy Hotel             0                           342               2015
# 1  Fancy Hotel             0                           737               2015
# 2  Fancy Hotel             0                             7               2015
# 3  Fancy Hotel             0                            13               2015
# 4  Fancy Hotel             0                            14               2015
# 5  Fancy Hotel             0                            14               2015
# 6  Fancy Hotel             0                             0               2015
# 7  Fancy Hotel             0                             9               2015
# 8  Fancy Hotel             1                            85               2015
# 9  Fancy Hotel             1                            75               2015
#
#   month_arrival_date  week_number_arrival_date  day_of_month_arrival_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   type                             119390 non-null  object
#  1   cancellation                     119390 non-null  int64
#  2   days_between_booking_arrival     119390 non-null  int64
#  3   year_arrival_date                119390 non-null  int64
#  4   month_arrival_date               119390 non-null  object
#  5   week_number_arrival_date         119390 non-null  int64
#  6   day_of_month_arrival_date        119390 non-null  int64
#  7   num_weekend_nights               119390 non-null  int64
#  8   num_workweek_nights              119390 non-null  int64
#  9   num_adults                       119390 non-null  int64
#  10  num_children                     119386 non-null  float64
# ...

# %%
df[df.id_person_booking.notnull()].cancellation.value_counts()
# Out:
# 0    5606
# 1    1191
# Name: cancellation, dtype: int64

# %%
df.cancellation.value_counts()
# Out:
# 0    75166
# 1    44224
# Name: cancellation, dtype: int64

# %%
df[df['arrival_date']<'2017-01-01'].cancellation.value_counts()/df[df['arrival_date']<'2017-01-01'].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/survival/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/anaconda3/envs/survival/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/survival/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'arrival_date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[df['arrival_date']>='2017-01-01'].cancellation.value_counts()/df[df['arrival_date']>='2017-01-01'].shape[0]

# %%
df.week_number_arrival_date.hist()

# %%
df.isnull().sum()

# %%
df.describe().transpose()

# %%
df.columns

# %%
ax = df[['num_weekend_nights',
       'num_workweek_nights', 'num_adults', 'num_children', 'num_babies',
       'num_previous_cancellations', 'num_previous_stays',
       'changes_between_booking_arrival',
       'total_of_special_requests']].boxplot(fontsize=10, vert=False)

# %%
sns.histplot(df.days_between_booking_arrival,kde=True)

# %%
corr_metrics = df[['cancellation', 'days_between_booking_arrival','num_weekend_nights', 'num_workweek_nights',
       'num_previous_stays', 'changes_between_booking_arrival','avg_price']].corr()
corr_metrics.style.background_gradient()

# %%
sns.pairplot(df[['cancellation', 'num_previous_stays', 'changes_between_booking_arrival','avg_price']])

# %%
sns.histplot(df.avg_price,kde=True)

# %%
d = {'April': 4,
 'August': 8,
 'December': 12,
 'February': 2,
 'January': 1,
 'July': 7,
 'June': 6,
 'March': 3,
 'May': 5,
 'November': 11,
 'October': 10,
 'September': 9}

df['month_arrival_date_index'] = df['month_arrival_date'].map(d)
df['arrival_date'] = pd.to_datetime(dict(year=df.year_arrival_date, month=df.month_arrival_date_index, day=df.day_of_month_arrival_date))

# %%
#df.index = pd.to_datetime(dict(year=df.year_arrival_date, month=df.month_arrival_date_index, day=df.day_of_month_arrival_date))
#sorted(df[df.month_arrival_date_index==2].day_of_month_arrival_date.unique())
#df = df.reset_index()

# %%
cancelyrs = df.groupby('year_arrival_date', as_index=True).agg(cancel_mean=('cancellation','mean'),cancel_std=('cancellation','sem'))
cancelyrs
# Out:
#                    cancel_mean  cancel_std
# year_arrival_date
# 2015                  0.370158    0.003256
# 2016                  0.358633    0.002014
# 2017                  0.386979    0.002415

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df['A'], df['B'], df['C'], df['D'])
print(fvalue, pvalue)

# %%
cancelyrs.plot(y='cancel_mean',yerr='cancel_std')
# Out:
# <AxesSubplot:xlabel='year_arrival_date'>

# %%
df_cancel = df.groupby('arrival_date', as_index=True).cancellation.agg(cancel_sum='sum')
df_cancel['rolling_avg_cancel'] = df_cancel.cancel_sum.rolling(30).mean()

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df_cancel.loc[:'2015-12-31'].cancel_sum.values, 
                                df_cancel.loc['2016-01-01':'2017-01-01'].cancel_sum.values, 
                                df_cancel.loc['2017-01-01':].cancel_sum.values)
print(fvalue, pvalue)
# Out:
# 15.005856973610877 4.014485520352942e-07

# %%
df_cancel.loc[:'2015-12-31'].cancel_sum.values
# Out:
# array([ 19,  57,  19,  43,  16,  34,  25,  24,  51,   9,  42,  26,  45,
#         11,  48,  62,  45,  78,  18,  72,  44,  84,  59,  15, 103,  15,
#         97,   6,  16,  58,  18,  50,   7, 110,  12,  64,  27,  56, 100,
#         14,  79,  28,  50,  54, 210,  89,  24,  80,  26,   8,  50,  13,
#         59,  17,  69,  59,  49,  61,  25,  20,  52,  36,  18,  55,  66,
#         42, 145,  25,  41,  34,  64,  75,  79,  89,  14,  36,  41,  51,
#        194, 203,  76,  42,  79,  14,  45, 120, 123, 114,  18,  43,  47,
#        101,  34,  21, 151,  70, 115,  69,  58,  80,  78, 119,  34,  47,
#          8,   4,  67, 222,  68,  18,  59,  15,  28,  12,  13,  99,  13,
#         36,   1,   8,  54,  38,  93,   8,  22,   5,  24,   5,  17,  31,
#          9,  37,  11,  21,  20,  31,   6,   4,  11,   7,  12,  11,  54,
#          5,   2,  71,   4,   5,   7,  18,  14,   5,   9,  12,   6,  24,
#         47, 193,  19,   4, 167,  84,   3,   7,   3,   4,   3,   3,   2,
# ...

# %%
canceldic = {'2015': }

# %%
# Plot settings
#%config InlineBackend.figure_format='retina'
plt.rcParams["figure.figsize"] = (18, 10)
plt.style.use('ggplot')

# Plot all time series in the df DataFrame
ax = df_cancel.plot(
    #colormap="Spectral",  # Set a colormap to avoid overlapping colors
    fontsize=10,  # Set fontsize
    linewidth=2, # Set width of lines
)

# Set labels and legend
ax.set_xlabel("Date", fontsize=12)  # X axis text
ax.set_ylabel("Number of cancellations", fontsize=12) # Set font size
#ax.set_title("Unemployment rate of U.S. workers by industry", fontsize=15)
ax.legend(
    loc="center left",  # Set location of legend within bounding box
    bbox_to_anchor=(1.0, 0.5),  # Set location of bounding box
)

# Annotate your plots with vertical lines
#ax.axvline(
#    "2001-07-01",  # Position of vertical line
#    color="red",  # Color of line
#    linestyle="--",  # Style of line
#    linewidth=2, # Thickness of line
#)
#ax.axvline("2008-09-01", color="red", linestyle="--", linewidth=2)

# Show plot
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(df_cancel.cancel_sum,lags=366)
#df_cancel['cancel_sum']
